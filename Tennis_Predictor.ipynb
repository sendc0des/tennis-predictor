# %% [markdown]
# # Compiling the data (matches from 2000 to 2024)

# %%
import pandas as pd
import glob
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
match_files = glob.glob("tennis_data/20*.csv")
matches_raw = pd.concat((pd.read_csv(f) for f in match_files), ignore_index=True)

# %%
matches_raw.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2000-7308     Adelaide    Hard       32.0             A      20000103
# 1  2000-7308     Adelaide    Hard       32.0             A      20000103
# 2  2000-7308     Adelaide    Hard       32.0             A      20000103
# 3  2000-7308     Adelaide    Hard       32.0             A      20000103
# 4  2000-7308     Adelaide    Hard       32.0             A      20000103
#
#    match_num winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df  \
# 0          1      E113          1.0          NaN  ...       2.0   1.0   3.0
# 1          2      F324          NaN          NaN  ...       0.0   3.0   5.0
# 2          3      G352          NaN          NaN  ...       1.0  26.0   2.0
# 3          4      G379          7.0          NaN  ...       4.0   0.0   3.0
# 4          5      N250          3.0          NaN  ...       1.0   4.0   2.0
#
#   l_svpt  l_1stIn  l_1stWon  l_2ndWon l_SvGms  l_bpSaved l_bpFaced
# 0   59.0     37.0      25.0      13.0     9.0        2.0       4.0
# 1   42.0     15.0      13.0      12.0     8.0        0.0       3.0
# 2  103.0     59.0      49.0      22.0    16.0        4.0       5.0
# 3   49.0     22.0      12.0       8.0     8.0        1.0       6.0
# 4   73.0     40.0      25.0      16.0    10.0        7.0      10.0
#
# [5 rows x 49 columns]

# %% [markdown]
# # Dropping irrelevant columns

# %%
features_temp = [
    'winner_id', 'loser_id',  
    'winner_rank', 'loser_rank',    
    'winner_age', 'loser_age',    
    'winner_ht', 'loser_ht',
    'surface',
    'tourney_level',
    'round',
    'w_ace', 'l_ace',
    'w_df', 'l_df',
    'minutes', 'tourney_date'
]

matches = matches_raw[features_temp]
matches.head()
# Out:
#   winner_id loser_id  winner_rank  loser_rank  winner_age  loser_age  \
# 0      E113     C487          4.0        56.0      25.810     22.045
# 1      F324     K260         64.0        91.0      18.404     24.882
# 2      G352     A202         58.0       105.0      22.585     28.797
# 3      G379     I052         27.0        54.0      21.599     23.710
# 4      N250     D270         15.0       154.0      23.595     25.580
#
#    winner_ht  loser_ht surface tourney_level round  w_ace  l_ace  w_df  l_df  \
# 0      191.0     173.0    Hard             A   R32    6.0    1.0   0.0   3.0
# 1      185.0     191.0    Hard             A   R32    6.0    3.0   3.0   5.0
# 2      191.0     185.0    Hard             A   R32    8.0   26.0   3.0   2.0
# 3      175.0     180.0    Hard             A   R32    4.0    0.0   2.0   3.0
# 4      188.0     175.0    Hard             A   R32    6.0    4.0   2.0   2.0
#
#    minutes  tourney_date
# 0     76.0      20000103
# 1     45.0      20000103
# 2    115.0      20000103
# 3     65.0      20000103
# 4     68.0      20000103

# %%
matches = matches.rename(columns={'w_ace':'winner_ace', 'l_ace':'loser_ace', 'w_df':'winner_df', 'l_df':'loser_df'})

# %% [markdown]
# # Cleaning the dataset

# %%
matches = matches.dropna()

# %%
matches['surface'] = matches['surface'].str.capitalize()

round_mapping = {'R128':'128','R64':'64','R32':'32','R16':'16','QF':'QF','SF':'SF','F':'F'}
matches['round'] = matches['round'].replace(round_mapping)

# %% [markdown]
# # Feature Engineering

# %%
mask = np.random.rand(len(matches)) > 0.5

matches["player1"] = np.where(mask, matches["winner_id"], matches["loser_id"])
matches["player2"] = np.where(mask, matches["loser_id"], matches["winner_id"])

# %%
stats = ["rank", "age", "ht", "ace", "df"]

for stat in stats:
    matches[f"player1_{stat}"] = np.where(mask, matches[f"winner_{stat}"], matches[f"loser_{stat}"])
    matches[f"player2_{stat}"] = np.where(mask, matches[f"loser_{stat}"], matches[f"winner_{stat}"])

# %%
matches["winner_binary"] = np.where(matches["winner_id"] == matches["player1"], 1, 0)

# %%
matches["rank_diff"] = matches["player1_rank"] - matches["player2_rank"]
matches["age_diff"]  = matches["player1_age"] - matches["player2_age"]
matches["ht_diff"] = matches["player1_ht"] - matches["player2_ht"]
matches["ace_diff"] = matches["player1_ace"] - matches["player2_ace"]
matches["df_diff"] = matches["player1_df"] - matches["player2_df"]

# %%
columns_to_drop = ['winner_id', 'loser_id', 'winner_rank', 'loser_rank', 'winner_age',
       'loser_age', 'winner_ht', 'loser_ht', 
       'winner_ace', 'loser_ace', 'winner_df', 'loser_df',
       'player1_rank', 'player2_rank', 'player1_age',
       'player2_age', 'player1_ht', 'player2_ht', 'player1_ace', 'player2_ace',
       'player1_df', 'player2_df']

matches = matches.drop(columns=columns_to_drop)

# %%
matches.head()
# Out:
#   surface tourney_level round  minutes  tourney_date player1 player2  \
# 0    Hard             A    32     76.0      20000103    C487    E113
# 1    Hard             A    32     45.0      20000103    K260    F324
# 2    Hard             A    32    115.0      20000103    G352    A202
# 3    Hard             A    32     65.0      20000103    G379    I052
# 4    Hard             A    32     68.0      20000103    D270    N250
#
#    winner_binary  rank_diff  age_diff  ht_diff  ace_diff  df_diff
# 0              0       52.0    -3.765    -18.0      -5.0      3.0
# 1              0       27.0     6.478      6.0      -3.0      2.0
# 2              1      -47.0    -6.212      6.0     -18.0      1.0
# 3              1      -27.0    -2.111     -5.0       4.0     -1.0
# 4              0      139.0     1.985    -13.0      -2.0      0.0

# %%
def insertH2H_winrate_past(matches):
    """
    Adds 'h2h_winrate' = player1's win rate vs player2
    based only on past matches (before the current match).
    """

    # Sort matches by date (very important!)
    matches = matches.sort_values(by='tourney_date').reset_index(drop=True)

    h2h_winrate = []
    history = {}

    for _, row in matches.iterrows():
        p1, p2, winner = row['player1'], row['player2'], row['winner_binary']

        # --- Lookup history ---
        past = history.get((p1, p2), {"wins": 0, "total": 0})
        if past["total"] == 0:
            h2h_winrate.append(None)  # no history yet
        else:
            h2h_winrate.append(past["wins"] / past["total"])

        # --- Update history AFTER recording winrate ---
        # Case 1: p1 vs p2
        history.setdefault((p1, p2), {"wins": 0, "total": 0})
        history.setdefault((p2, p1), {"wins": 0, "total": 0})

        if winner == 1:  # player1 wins
            history[(p1, p2)]["wins"] += 1
        else:  # player2 wins
            history[(p2, p1)]["wins"] += 1

        history[(p1, p2)]["total"] += 1
        history[(p2, p1)]["total"] += 1

    matches['h2h_winrate'] = h2h_winrate
    return matches

matches = insertH2H_winrate_past(matches)

# %%
def add_recent_form_diff(matches, window=5):
    """
    Adds a single feature: recent form difference (player1 - player2).
    Each player's recent form = win ratio of last N matches (excluding current match).
    """

    # Sort chronologically (important!)
    matches = matches.sort_values(by='tourney_date').reset_index(drop=True)

    recent_form_diff = []
    history = {}

    for _, row in matches.iterrows():
        p1, p2, winner = row['player1'], row['player2'], row['winner_binary']

        # --- Player1 ---
        past_p1 = history.get(p1, [])
        if len(past_p1) == 0:
            form_p1 = None
        else:
            last_matches = past_p1[-window:]
            form_p1 = sum(last_matches) / len(last_matches)

        # --- Player2 ---
        past_p2 = history.get(p2, [])
        if len(past_p2) == 0:
            form_p2 = None
        else:
            last_matches = past_p2[-window:]
            form_p2 = sum(last_matches) / len(last_matches)

        # --- Difference ---
        if form_p1 is None or form_p2 is None:
            recent_form_diff.append(None)
        else:
            recent_form_diff.append(form_p1 - form_p2)

        # --- Update history AFTER computing form ---
        history.setdefault(p1, []).append(1 if winner == 1 else 0)
        history.setdefault(p2, []).append(1 if winner == 0 else 0)

    matches['recent_form_diff'] = recent_form_diff

    return matches

matches = add_recent_form_diff(matches)

# %%
matches = matches.dropna()

# %% [markdown]
# # Filter out our dataset from the matches dataframe

# %%
x_features = ['surface', 'tourney_level', 'round', 'minutes',
            'rank_diff', 'age_diff',
            'ht_diff', 'ace_diff', 'df_diff', 'h2h_winrate', 'recent_form_diff']
X = matches[x_features]
y = matches['winner_binary']

# %% [markdown]
# # One hot encode the features

# %%
X = pd.get_dummies(X,
                   columns = ['surface', 'tourney_level', 'round'],
                   drop_first = True
                )

# %% [markdown]
# # Split the dataset

# %%
X_train , X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42, stratify=y)

# %%
X_train_fit, X_eval, y_train_fit, y_eval = train_test_split(X_train, y_train, train_size=0.8, random_state=42, stratify=y_train)

# %% [markdown]
# # Create xgboost model

# %%
model = XGBClassifier(n_estimators = 500, learning_rate=0.1, verbosity=1, random_state=42, early_stopping_rounds=50)
model.fit(X_train_fit, y_train_fit, eval_set=[(X_eval, y_eval)])
# Out:
# [0]	validation_0-logloss:0.67130
# [1]	validation_0-logloss:0.65370
# [2]	validation_0-logloss:0.63926
# [3]	validation_0-logloss:0.62707
# [4]	validation_0-logloss:0.61676
# [5]	validation_0-logloss:0.60812
# [6]	validation_0-logloss:0.60102
# [7]	validation_0-logloss:0.59458
# [8]	validation_0-logloss:0.58944
# [9]	validation_0-logloss:0.58474
# [10]	validation_0-logloss:0.58065
# [11]	validation_0-logloss:0.57664
# [12]	validation_0-logloss:0.57383
# [13]	validation_0-logloss:0.57099
# [14]	validation_0-logloss:0.56870
# [15]	validation_0-logloss:0.56659
# [16]	validation_0-logloss:0.56498
# [17]	validation_0-logloss:0.56381
# [18]	validation_0-logloss:0.56237
# [19]	validation_0-logloss:0.56131
# [20]	validation_0-logloss:0.56023
# [21]	validation_0-logloss:0.55912
# [22]	validation_0-logloss:0.55813
# [23]	validation_0-logloss:0.55769
# [24]	validation_0-logloss:0.55729
# [25]	validation_0-logloss:0.55709
# [26]	validation_0-logloss:0.55642
# [27]	validation_0-logloss:0.55607
# [28]	validation_0-logloss:0.55568
# [29]	validation_0-logloss:0.55513
# [30]	validation_0-logloss:0.55479
# [31]	validation_0-logloss:0.55443
# [32]	validation_0-logloss:0.55425
# [33]	validation_0-logloss:0.55407
# [34]	validation_0-logloss:0.55408
# [35]	validation_0-logloss:0.55366
# [36]	validation_0-logloss:0.55361
# [37]	validation_0-logloss:0.55343
# [38]	validation_0-logloss:0.55340
# [39]	validation_0-logloss:0.55334
# [40]	validation_0-logloss:0.55318
# [41]	validation_0-logloss:0.55314
# [42]	validation_0-logloss:0.55323
# [43]	validation_0-logloss:0.55331
# [44]	validation_0-logloss:0.55332
# [45]	validation_0-logloss:0.55304
# [46]	validation_0-logloss:0.55320
# [47]	validation_0-logloss:0.55293
# [48]	validation_0-logloss:0.55293
# [49]	validation_0-logloss:0.55293
# [50]	validation_0-logloss:0.55285
# [51]	validation_0-logloss:0.55315
# [52]	validation_0-logloss:0.55310
# [53]	validation_0-logloss:0.55315
# [54]	validation_0-logloss:0.55296
# [55]	validation_0-logloss:0.55293
# [56]	validation_0-logloss:0.55305
# [57]	validation_0-logloss:0.55307
# [58]	validation_0-logloss:0.55283
# [59]	validation_0-logloss:0.55297
# [60]	validation_0-logloss:0.55294
# [61]	validation_0-logloss:0.55308
# [62]	validation_0-logloss:0.55313
# [63]	validation_0-logloss:0.55317
# [64]	validation_0-logloss:0.55333
# [65]	validation_0-logloss:0.55323
# [66]	validation_0-logloss:0.55324
# [67]	validation_0-logloss:0.55339
# [68]	validation_0-logloss:0.55317
# [69]	validation_0-logloss:0.55316
# [70]	validation_0-logloss:0.55342
# [71]	validation_0-logloss:0.55347
# [72]	validation_0-logloss:0.55338
# [73]	validation_0-logloss:0.55344
# [74]	validation_0-logloss:0.55335
# [75]	validation_0-logloss:0.55360
# [76]	validation_0-logloss:0.55379
# [77]	validation_0-logloss:0.55390
# [78]	validation_0-logloss:0.55399
# [79]	validation_0-logloss:0.55391
# [80]	validation_0-logloss:0.55394
# [81]	validation_0-logloss:0.55429
# [82]	validation_0-logloss:0.55433
# [83]	validation_0-logloss:0.55431
# [84]	validation_0-logloss:0.55444
# [85]	validation_0-logloss:0.55459
# [86]	validation_0-logloss:0.55484
# [87]	validation_0-logloss:0.55497
# [88]	validation_0-logloss:0.55514
# [89]	validation_0-logloss:0.55503
# [90]	validation_0-logloss:0.55510
# [91]	validation_0-logloss:0.55526
# [92]	validation_0-logloss:0.55530
# [93]	validation_0-logloss:0.55525
# [94]	validation_0-logloss:0.55508
# [95]	validation_0-logloss:0.55503
# [96]	validation_0-logloss:0.55527
# [97]	validation_0-logloss:0.55540
# [98]	validation_0-logloss:0.55556
# [99]	validation_0-logloss:0.55552
# [100]	validation_0-logloss:0.55582
# [101]	validation_0-logloss:0.55595
# [102]	validation_0-logloss:0.55604
# [103]	validation_0-logloss:0.55603
# [104]	validation_0-logloss:0.55603
# [105]	validation_0-logloss:0.55627
# [106]	validation_0-logloss:0.55646
# [107]	validation_0-logloss:0.55635
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print(accuracy_score(model.predict(X_test), y_test))
# Out:
# 0.7019494119542452

# %% [markdown]
# # Save the model

# %%
# import xgboost as xgb
# model.save_model("xgb_model.json")

# %% [markdown]
# # Load the model

# %%
# import xgboost as xgb
# model = xgb.Booster()
# model.load_model("xgb_model.json")

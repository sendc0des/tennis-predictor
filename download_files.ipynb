# %%
import os
import requests

# %%
DATA_DIR = "tennis_data"
os.makedirs(DATA_DIR, exist_ok=True)

BASE_URL = "https://raw.githubusercontent.com/Tennismylife/TML-Database/refs/heads/master/"

files_to_download = []

for year in range(1968, 2025):
    files_to_download.append(f"{year}.csv")

files_to_download.append("ATP_Database.csv")

for filename in files_to_download:
    url = BASE_URL + filename
    local_path = os.path.join(DATA_DIR, filename)
    print(f"Downloading {filename}...")
    response = requests.get(url)
    if response.status_code == 200:
        with open(local_path, "wb") as f:
            f.write(response.content)
        print(f"Saved to {local_path}")
    else:
        print(f"⚠️ Failed to download {filename} (status {response.status_code})")

print("\n✅ All selected files downloaded!")
# Out:
# Downloading 1968.csv...
# Saved to tennis_data\1968.csv
# Downloading 1969.csv...
# Saved to tennis_data\1969.csv
# Downloading 1970.csv...
# Saved to tennis_data\1970.csv
# Downloading 1971.csv...
# Saved to tennis_data\1971.csv
# Downloading 1972.csv...
# Saved to tennis_data\1972.csv
# Downloading 1973.csv...
# Saved to tennis_data\1973.csv
# Downloading 1974.csv...
# Saved to tennis_data\1974.csv
# Downloading 1975.csv...
# Saved to tennis_data\1975.csv
# Downloading 1976.csv...
# Saved to tennis_data\1976.csv
# Downloading 1977.csv...
# Saved to tennis_data\1977.csv
# Downloading 1978.csv...
# Saved to tennis_data\1978.csv
# Downloading 1979.csv...
# Saved to tennis_data\1979.csv
# Downloading 1980.csv...
# Saved to tennis_data\1980.csv
# Downloading 1981.csv...
# Saved to tennis_data\1981.csv
# Downloading 1982.csv...
# Saved to tennis_data\1982.csv
# Downloading 1983.csv...
# Saved to tennis_data\1983.csv
# Downloading 1984.csv...
# Saved to tennis_data\1984.csv
# Downloading 1985.csv...
# Saved to tennis_data\1985.csv
# Downloading 1986.csv...
# Saved to tennis_data\1986.csv
# Downloading 1987.csv...
# Saved to tennis_data\1987.csv
# Downloading 1988.csv...
# Saved to tennis_data\1988.csv
# Downloading 1989.csv...
# Saved to tennis_data\1989.csv
# Downloading 1990.csv...
# Saved to tennis_data\1990.csv
# Downloading 1991.csv...
# Saved to tennis_data\1991.csv
# Downloading 1992.csv...
# Saved to tennis_data\1992.csv
# Downloading 1993.csv...
# Saved to tennis_data\1993.csv
# Downloading 1994.csv...
# Saved to tennis_data\1994.csv
# Downloading 1995.csv...
# Saved to tennis_data\1995.csv
# Downloading 1996.csv...
# Saved to tennis_data\1996.csv
# Downloading 1997.csv...
# Saved to tennis_data\1997.csv
# Downloading 1998.csv...
# Saved to tennis_data\1998.csv
# Downloading 1999.csv...
# Saved to tennis_data\1999.csv
# Downloading 2000.csv...
# Saved to tennis_data\2000.csv
# Downloading 2001.csv...
# Saved to tennis_data\2001.csv
# Downloading 2002.csv...
# Saved to tennis_data\2002.csv
# Downloading 2003.csv...
# Saved to tennis_data\2003.csv
# Downloading 2004.csv...
# Saved to tennis_data\2004.csv
# Downloading 2005.csv...
# Saved to tennis_data\2005.csv
# Downloading 2006.csv...
# Saved to tennis_data\2006.csv
# Downloading 2007.csv...
# Saved to tennis_data\2007.csv
# Downloading 2008.csv...
# Saved to tennis_data\2008.csv
# Downloading 2009.csv...
# Saved to tennis_data\2009.csv
# Downloading 2010.csv...
# Saved to tennis_data\2010.csv
# Downloading 2011.csv...
# Saved to tennis_data\2011.csv
# Downloading 2012.csv...
# Saved to tennis_data\2012.csv
# Downloading 2013.csv...
# Saved to tennis_data\2013.csv
# Downloading 2014.csv...
# Saved to tennis_data\2014.csv
# Downloading 2015.csv...
# Saved to tennis_data\2015.csv
# Downloading 2016.csv...
# Saved to tennis_data\2016.csv
# Downloading 2017.csv...
# Saved to tennis_data\2017.csv
# Downloading 2018.csv...
# Saved to tennis_data\2018.csv
# Downloading 2019.csv...
# Saved to tennis_data\2019.csv
# Downloading 2020.csv...
# Saved to tennis_data\2020.csv
# Downloading 2021.csv...
# Saved to tennis_data\2021.csv
# Downloading 2022.csv...
# Saved to tennis_data\2022.csv
# Downloading 2023.csv...
# Saved to tennis_data\2023.csv
# Downloading 2024.csv...
# Saved to tennis_data\2024.csv
# Downloading ATP_Database.csv...
# Saved to tennis_data\ATP_Database.csv
#
# ✅ All selected files downloaded!

# %% [markdown]
# # Compiling the data (matches from 2000 to 2024)

# %%
import pandas as pd
import glob
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
all_csv_files = glob.glob("tennis_data/*.csv")
all_csv_files.pop()
matches = pd.concat(pd.read_csv(f) for f in all_csv_files)

# %%
matches.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  1968-9346  Cape Town-1    Hard       64.0             A      19680101
# 1  1968-9346  Cape Town-1    Hard       64.0             A      19680101
# 2  1968-9346  Cape Town-1    Hard       64.0             A      19680101
# 3  1968-9346  Cape Town-1    Hard       64.0             A      19680101
# 4  1968-9346  Cape Town-1    Hard       64.0             A      19680101
#
#    match_num winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df  \
# 0        1.0      BB88          NaN          NaN  ...       NaN   NaN   NaN
# 1        2.0      C090          NaN          NaN  ...       NaN   NaN   NaN
# 2        3.0      F068          NaN          NaN  ...       NaN   NaN   NaN
# 3        4.0      G079          NaN          NaN  ...       NaN   NaN   NaN
# 4        5.0      GF84          NaN          NaN  ...       NaN   NaN   NaN
#
#   l_svpt  l_1stIn  l_1stWon  l_2ndWon l_SvGms  l_bpSaved l_bpFaced
# 0    NaN      NaN       NaN       NaN     NaN        NaN       NaN
# 1    NaN      NaN       NaN       NaN     NaN        NaN       NaN
# 2    NaN      NaN       NaN       NaN     NaN        NaN       NaN
# 3    NaN      NaN       NaN       NaN     NaN        NaN       NaN
# 4    NaN      NaN       NaN       NaN     NaN        NaN       NaN
#
# [5 rows x 49 columns]

# %%
matches.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %% [markdown]
# # Cleaning the dataset

# %%
features_temp = [
    'winner_id', 'loser_id',  
    'winner_rank', 'loser_rank',    
    'winner_age', 'loser_age',    
    'winner_ht', 'loser_ht',
    'winner_hand', 'loser_hand',
    'surface',
    'tourney_level',
    'round',
    'w_ace', 'l_ace',
    'w_df', 'l_df',
    'w_svpt', 'l_svpt',
    'w_1stWon', 'l_1stWon',
    'w_SvGms', 'l_SvGms',
    'minutes', 'tourney_date'
]

matches = matches[features_temp]
matches.head()
# Out:
#   winner_id loser_id  winner_rank  loser_rank  winner_age  loser_age  \
# 0      BB88     M0M6          NaN         NaN      24.884        NaN
# 1      C090     Y008          NaN         NaN      24.493     19.053
# 2      F068     RD88          NaN         NaN      19.595        NaN
# 3      G079     P576          NaN         NaN      24.159     23.513
# 4      GF84     LE16          NaN         NaN      19.228     18.130
#
#    winner_ht  loser_ht surface tourney_level  ... winner_hand  loser_hand  \
# 0        NaN       NaN    Hard             A  ...         NaN         NaN
# 1        NaN       NaN    Hard             A  ...           L           R
# 2        NaN       NaN    Hard             A  ...           R         NaN
# 3      188.0       NaN    Hard             A  ...           R         NaN
# 4        NaN       NaN    Hard             A  ...         NaN         NaN
#
#    w_svpt  l_svpt  w_1stWon l_1stWon w_SvGms  l_SvGms  minutes  tourney_date
# 0     NaN     NaN       NaN      NaN     NaN      NaN      NaN      19680101
# 1     NaN     NaN       NaN      NaN     NaN      NaN      NaN      19680101
# 2     NaN     NaN       NaN      NaN     NaN      NaN      NaN      19680101
# 3     NaN     NaN       NaN      NaN     NaN      NaN      NaN      19680101
# 4     NaN     NaN       NaN      NaN     NaN      NaN      NaN      19680101
#
# [5 rows x 25 columns]

# %%
matches = matches.dropna()

# %%
matches = matches.rename(columns={'w_ace':'winner_ace', 'l_ace':'loser_ace', 'w_df':'winner_df', 'l_df':'loser_df', 
                                  'w_svpt':'winner_svpt', 'l_svpt':'loser_svpt', 'w_1stWon':'winner_1stWon', 'l_1stWon':'loser_1stWon',
                                  'w_SvGms':'winner_SvGms', 'l_SvGms':'loser_SvGms'})

# %%
# matches['surface'] = matches['surface'].str.capitalize()

round_mapping = {'R128':'128','R64':'64','R32':'32','R16':'16','QF':'QF','SF':'SF','F':'F'}
matches['round'] = matches['round'].replace(round_mapping)

# %%
matches.head()
# Out:
#   winner_id loser_id  winner_rank  loser_rank  winner_age  loser_age  \
# 0      L206     B028         56.0         2.0      20.769     23.107
# 1      Z006     K021        304.0        75.0      27.441     24.624
# 2      K030     P004         82.0        69.0      24.884     23.050
# 3      W136     R186         50.0        84.0      19.748     20.876
# 4      R023     B350         88.0        28.0      24.427     19.956
#
#    winner_ht  loser_ht surface tourney_level  ... winner_svpt  loser_svpt  \
# 0      193.0     191.0    Hard             A  ...        96.0        95.0
# 1      198.0     175.0    Hard             A  ...       101.0        84.0
# 2      191.0     183.0    Hard             A  ...        54.0        60.0
# 3      178.0     180.0    Hard             A  ...        60.0        74.0
# 4      185.0     188.0    Hard             A  ...        72.0        77.0
#
#    winner_1stWon  loser_1stWon  winner_SvGms loser_SvGms minutes  \
# 0           39.0          44.0          15.0        16.0   130.0
# 1           45.0          35.0          15.0        15.0   119.0
# 2           24.0          22.0           8.0         8.0    71.0
# 3           30.0          30.0           9.0        10.0    85.0
# 4           33.0          28.0          10.0        11.0    90.0
#
#    tourney_date  player1  player2
# 0      19901231     B028     L206
# 1      19901231     Z006     K021
# 2      19901231     K030     P004
# 3      19901231     R186     W136
# 4      19901231     R023     B350
#
# [5 rows x 27 columns]

# %% [markdown]
# # Feature Engineering

# %%
mask = np.random.rand(len(matches)) > 0.5

matches["player1"] = np.where(mask, matches["winner_id"], matches["loser_id"])
matches["player2"] = np.where(mask, matches["loser_id"], matches["winner_id"])

# %%
stats = ["rank", "age", "ht", "ace", "df", "svpt", "1stWon", "SvGms"]

for stat in stats:
    matches[f"player1_{stat}"] = np.where(mask, matches[f"winner_{stat}"], matches[f"loser_{stat}"])
    matches[f"player2_{stat}"] = np.where(mask, matches[f"loser_{stat}"], matches[f"winner_{stat}"])

# %%
matches["winner_binary"] = np.where(matches["winner_id"] == matches["player1"], 1, 0)

# %%
matches["rank_diff"] = matches["player1_rank"] - matches["player2_rank"]
matches["age_diff"]  = matches["player1_age"] - matches["player2_age"]
matches["ht_diff"] = matches["player1_ht"] - matches["player2_ht"]
matches["ace_diff"] = matches["player1_ace"] - matches["player2_ace"]
matches["df_diff"] = matches["player1_df"] - matches["player2_df"]
matches["svpt_diff"] = matches["player1_svpt"] - matches["player2_svpt"]
matches["1stWon_diff"] = matches["player1_1stWon"] - matches["player2_1stWon"]
matches["SvGms_diff"] = matches["player1_SvGms"] - matches["player2_SvGms"]

# %%
columns_to_drop = ['winner_id', 'loser_id', 'winner_rank', 'loser_rank', 'winner_age',
       'loser_age', 'winner_ht', 'loser_ht', 
       'winner_ace', 'loser_ace', 'winner_df', 'loser_df',
       'player1_rank', 'player2_rank', 'player1_age',
       'player2_age', 'player1_ht', 'player2_ht', 'player1_ace', 'player2_ace',
       'player1_df', 'player2_df', 'player1_svpt', 'player2_svpt', 'player1_1stWon', 'player2_1stWon',
       'player1_SvGms', 'player2_SvGms']

matches = matches.drop(columns=columns_to_drop)

# %%
matches.head()
# Out:
#   surface tourney_level round winner_hand loser_hand  winner_svpt  loser_svpt  \
# 0    Hard             A    32           R          R         96.0        95.0
# 1    Hard             A    32           R          L        101.0        84.0
# 2    Hard             A    32           R          R         54.0        60.0
# 3    Hard             A    32           R          R         60.0        74.0
# 4    Hard             A    32           R          R         72.0        77.0
#
#    winner_1stWon  loser_1stWon  winner_SvGms  ...  player2  winner_binary  \
# 0           39.0          44.0          15.0  ...     L206              0
# 1           45.0          35.0          15.0  ...     K021              1
# 2           24.0          22.0           8.0  ...     P004              1
# 3           30.0          30.0           9.0  ...     W136              0
# 4           33.0          28.0          10.0  ...     B350              1
#
#    rank_diff age_diff ht_diff  ace_diff  df_diff  svpt_diff  1stWon_diff  \
# 0      -54.0    2.338    -2.0       2.0      1.0       -1.0          5.0
# 1      229.0    2.817    23.0      11.0      2.0       17.0         10.0
# 2       13.0    1.834     8.0       4.0     -1.0       -6.0          2.0
# 3       34.0    1.128     2.0       1.0      3.0       14.0          0.0
# 4       60.0    4.471    -3.0       2.0      0.0       -5.0          5.0
#
#    SvGms_diff
# 0         1.0
# 1         0.0
# 2         0.0
# 3         1.0
# 4        -1.0
#
# [5 rows x 24 columns]

# %%
def insertH2H_winrate_past(matches):
    """
    Adds 'h2h_winrate' = player1's win rate vs player2
    based only on past matches (before the current match).
    """

    # Sort matches by date (very important!)
    matches = matches.sort_values(by='tourney_date').reset_index(drop=True)

    h2h_winrate = []
    history = {}

    for _, row in matches.iterrows():
        p1, p2, winner = row['player1'], row['player2'], row['winner_binary']

        # --- Lookup history ---
        past = history.get((p1, p2), {"wins": 0, "total": 0})
        if past["total"] == 0:
            h2h_winrate.append(0.5)# no history yet
        else:
            h2h_winrate.append(past["wins"] / past["total"])
        # --- Update history AFTER recording winrate ---
        # Case 1: p1 vs p2
        history.setdefault((p1, p2), {"wins": 0, "total": 0})
        history.setdefault((p2, p1), {"wins": 0, "total": 0})

        if winner == 1:  # player1 wins
            history[(p1, p2)]["wins"] += 1
        else:  # player2 wins
            history[(p2, p1)]["wins"] += 1

        history[(p1, p2)]["total"] += 1
        history[(p2, p1)]["total"] += 1

    matches['h2h_winrate'] = h2h_winrate
    return matches

matches = insertH2H_winrate_past(matches)

# %%
def add_recent_form_diff(matches, window=5):
    """
    Adds a single feature: recent form difference (player1 - player2).
    Each player's recent form = win ratio of last N matches (excluding current match).
    """

    # Sort chronologically (important!)
    matches = matches.sort_values(by='tourney_date').reset_index(drop=True)

    recent_form_diff = []
    history = {}

    for _, row in matches.iterrows():
        p1, p2, winner = row['player1'], row['player2'], row['winner_binary']

        # --- Player1 ---
        past_p1 = history.get(p1, [])
        if len(past_p1) == 0:
            form_p1 = None
        else:
            last_matches = past_p1[-window:]
            form_p1 = sum(last_matches) / len(last_matches)

        # --- Player2 ---
        past_p2 = history.get(p2, [])
        if len(past_p2) == 0:
            form_p2 = None
        else:
            last_matches = past_p2[-window:]
            form_p2 = sum(last_matches) / len(last_matches)

        # --- Difference ---
        if form_p1 is None or form_p2 is None:
            recent_form_diff.append(None)
        else:
            recent_form_diff.append(form_p1 - form_p2)

        # --- Update history AFTER computing form ---
        history.setdefault(p1, []).append(1 if winner == 1 else 0)
        history.setdefault(p2, []).append(1 if winner == 0 else 0)

    matches['recent_form_diff'] = recent_form_diff

    return matches

matches = add_recent_form_diff(matches)

# %%
matches.columns
# Out:
# Index(['surface', 'tourney_level', 'round', 'winner_hand', 'loser_hand',
#        'winner_svpt', 'loser_svpt', 'winner_1stWon', 'loser_1stWon',
#        'winner_SvGms', 'loser_SvGms', 'minutes', 'tourney_date', 'player1',
#        'player2', 'winner_binary', 'rank_diff', 'age_diff', 'ht_diff',
#        'ace_diff', 'df_diff', 'svpt_diff', '1stWon_diff', 'SvGms_diff',
#        'h2h_winrate', 'recent_form_diff'],
#       dtype='object')

# %% [markdown]
# # Filter out our dataset from the matches dataframe

# %%
X_features = ['surface', 'tourney_level', 'round', 'minutes',
            'rank_diff', 'age_diff',
            'ht_diff', 'ace_diff', 'df_diff', 'svpt_diff', '1stWon_diff', 'SvGms_diff', 'h2h_winrate', 'recent_form_diff']
X = matches[X_features]
y = matches['winner_binary']

# %% [markdown]
# # One hot encode the features

# %%
X = pd.get_dummies(X,
                   columns = ['surface', 'tourney_level', 'round'],
                   drop_first = True
                )

# %% [markdown]
# # Split the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42, stratify=y)

# %%
X_train_fit, X_eval, y_train_fit, y_eval = train_test_split(X_train, y_train, train_size=0.8, random_state=42, stratify=y_train)

# %%
X_test.head()
# Out:
#        minutes  rank_diff  age_diff  ht_diff  ace_diff  df_diff  svpt_diff  \
# 17390    122.0      214.0     0.789     -6.0       1.0      2.0       25.0
# 20153     54.0      570.0     3.239     -5.0      -5.0     -2.0       -4.0
# 80985    119.0       13.0    -6.582    -10.0      -1.0     -2.0      -25.0
# 22740     54.0      -25.0    -5.804     -2.0      -4.0      0.0       13.0
# 79905     76.0      -42.0    -4.266     -3.0       1.0     -2.0       -9.0
#
#        1stWon_diff  SvGms_diff  h2h_winrate  ...  tourney_level_M  \
# 17390         -1.0        -1.0          1.0  ...             True
# 20153         -9.0         0.0          0.5  ...            False
# 80985          2.0         1.0          0.0  ...            False
# 22740         -2.0         1.0          0.5  ...            False
# 79905         10.0         0.0          1.0  ...             True
#
#        tourney_level_O  round_16  round_32  round_64  round_BR  round_F  \
# 17390            False     False     False      True     False    False
# 20153            False     False      True     False     False    False
# 80985            False     False      True     False     False    False
# 22740            False     False     False     False     False    False
# 79905            False      True     False     False     False    False
#
#        round_QF  round_RR  round_SF
# 17390     False     False     False
# 20153     False     False     False
# 80985     False     False     False
# 22740      True     False     False
# 79905     False     False     False
#
# [5 rows x 27 columns]

# %% [markdown]
# # Create xgboost model

# %%
model = XGBClassifier(n_estimators = 500, learning_rate=0.1, verbosity=1, random_state=42, early_stopping_rounds=50)
model.fit(X_train_fit, y_train_fit, eval_set=[(X_eval, y_eval)])
# Out:
# [0]	validation_0-logloss:0.65229
# [1]	validation_0-logloss:0.61873
# [2]	validation_0-logloss:0.59030
# [3]	validation_0-logloss:0.56570
# [4]	validation_0-logloss:0.54518
# [5]	validation_0-logloss:0.52731
# [6]	validation_0-logloss:0.51211
# [7]	validation_0-logloss:0.49857
# [8]	validation_0-logloss:0.48675
# [9]	validation_0-logloss:0.47629
# [10]	validation_0-logloss:0.46719
# [11]	validation_0-logloss:0.45897
# [12]	validation_0-logloss:0.45191
# [13]	validation_0-logloss:0.44563
# [14]	validation_0-logloss:0.44015
# [15]	validation_0-logloss:0.43510
# [16]	validation_0-logloss:0.43052
# [17]	validation_0-logloss:0.42644
# [18]	validation_0-logloss:0.42279
# [19]	validation_0-logloss:0.41944
# [20]	validation_0-logloss:0.41619
# [21]	validation_0-logloss:0.41364
# [22]	validation_0-logloss:0.41108
# [23]	validation_0-logloss:0.40833
# [24]	validation_0-logloss:0.40628
# [25]	validation_0-logloss:0.40436
# [26]	validation_0-logloss:0.40252
# [27]	validation_0-logloss:0.40084
# [28]	validation_0-logloss:0.39951
# [29]	validation_0-logloss:0.39802
# [30]	validation_0-logloss:0.39687
# [31]	validation_0-logloss:0.39577
# [32]	validation_0-logloss:0.39481
# [33]	validation_0-logloss:0.39367
# [34]	validation_0-logloss:0.39289
# [35]	validation_0-logloss:0.39194
# [36]	validation_0-logloss:0.39123
# [37]	validation_0-logloss:0.39031
# [38]	validation_0-logloss:0.38972
# [39]	validation_0-logloss:0.38916
# [40]	validation_0-logloss:0.38861
# [41]	validation_0-logloss:0.38791
# [42]	validation_0-logloss:0.38738
# [43]	validation_0-logloss:0.38674
# [44]	validation_0-logloss:0.38633
# [45]	validation_0-logloss:0.38578
# [46]	validation_0-logloss:0.38532
# [47]	validation_0-logloss:0.38477
# [48]	validation_0-logloss:0.38441
# [49]	validation_0-logloss:0.38387
# [50]	validation_0-logloss:0.38348
# [51]	validation_0-logloss:0.38320
# [52]	validation_0-logloss:0.38278
# [53]	validation_0-logloss:0.38247
# [54]	validation_0-logloss:0.38206
# [55]	validation_0-logloss:0.38182
# [56]	validation_0-logloss:0.38165
# [57]	validation_0-logloss:0.38154
# [58]	validation_0-logloss:0.38137
# [59]	validation_0-logloss:0.38118
# [60]	validation_0-logloss:0.38100
# [61]	validation_0-logloss:0.38081
# [62]	validation_0-logloss:0.38059
# [63]	validation_0-logloss:0.38031
# [64]	validation_0-logloss:0.38008
# [65]	validation_0-logloss:0.37990
# [66]	validation_0-logloss:0.37975
# [67]	validation_0-logloss:0.37965
# [68]	validation_0-logloss:0.37948
# [69]	validation_0-logloss:0.37940
# [70]	validation_0-logloss:0.37926
# [71]	validation_0-logloss:0.37919
# [72]	validation_0-logloss:0.37912
# [73]	validation_0-logloss:0.37887
# [74]	validation_0-logloss:0.37874
# [75]	validation_0-logloss:0.37871
# [76]	validation_0-logloss:0.37847
# [77]	validation_0-logloss:0.37834
# [78]	validation_0-logloss:0.37826
# [79]	validation_0-logloss:0.37817
# [80]	validation_0-logloss:0.37819
# [81]	validation_0-logloss:0.37806
# [82]	validation_0-logloss:0.37799
# [83]	validation_0-logloss:0.37791
# [84]	validation_0-logloss:0.37791
# [85]	validation_0-logloss:0.37782
# [86]	validation_0-logloss:0.37772
# [87]	validation_0-logloss:0.37770
# [88]	validation_0-logloss:0.37741
# [89]	validation_0-logloss:0.37739
# [90]	validation_0-logloss:0.37729
# [91]	validation_0-logloss:0.37719
# [92]	validation_0-logloss:0.37719
# [93]	validation_0-logloss:0.37714
# [94]	validation_0-logloss:0.37718
# [95]	validation_0-logloss:0.37711
# [96]	validation_0-logloss:0.37705
# [97]	validation_0-logloss:0.37712
# [98]	validation_0-logloss:0.37714
# [99]	validation_0-logloss:0.37712
# [100]	validation_0-logloss:0.37711
# [101]	validation_0-logloss:0.37707
# [102]	validation_0-logloss:0.37702
# [103]	validation_0-logloss:0.37702
# [104]	validation_0-logloss:0.37709
# [105]	validation_0-logloss:0.37706
# [106]	validation_0-logloss:0.37706
# [107]	validation_0-logloss:0.37700
# [108]	validation_0-logloss:0.37696
# [109]	validation_0-logloss:0.37698
# [110]	validation_0-logloss:0.37696
# [111]	validation_0-logloss:0.37689
# [112]	validation_0-logloss:0.37690
# [113]	validation_0-logloss:0.37688
# [114]	validation_0-logloss:0.37689
# [115]	validation_0-logloss:0.37661
# [116]	validation_0-logloss:0.37663
# [117]	validation_0-logloss:0.37660
# [118]	validation_0-logloss:0.37654
# [119]	validation_0-logloss:0.37668
# [120]	validation_0-logloss:0.37660
# [121]	validation_0-logloss:0.37659
# [122]	validation_0-logloss:0.37653
# [123]	validation_0-logloss:0.37655
# [124]	validation_0-logloss:0.37663
# [125]	validation_0-logloss:0.37662
# [126]	validation_0-logloss:0.37659
# [127]	validation_0-logloss:0.37660
# [128]	validation_0-logloss:0.37655
# [129]	validation_0-logloss:0.37655
# [130]	validation_0-logloss:0.37651
# [131]	validation_0-logloss:0.37644
# [132]	validation_0-logloss:0.37642
# [133]	validation_0-logloss:0.37647
# [134]	validation_0-logloss:0.37656
# [135]	validation_0-logloss:0.37658
# [136]	validation_0-logloss:0.37649
# [137]	validation_0-logloss:0.37636
# [138]	validation_0-logloss:0.37645
# [139]	validation_0-logloss:0.37647
# [140]	validation_0-logloss:0.37643
# [141]	validation_0-logloss:0.37643
# [142]	validation_0-logloss:0.37648
# [143]	validation_0-logloss:0.37652
# [144]	validation_0-logloss:0.37650
# [145]	validation_0-logloss:0.37646
# [146]	validation_0-logloss:0.37648
# [147]	validation_0-logloss:0.37649
# [148]	validation_0-logloss:0.37651
# [149]	validation_0-logloss:0.37656
# [150]	validation_0-logloss:0.37655
# [151]	validation_0-logloss:0.37648
# [152]	validation_0-logloss:0.37652
# [153]	validation_0-logloss:0.37642
# [154]	validation_0-logloss:0.37648
# [155]	validation_0-logloss:0.37634
# [156]	validation_0-logloss:0.37635
# [157]	validation_0-logloss:0.37632
# [158]	validation_0-logloss:0.37629
# [159]	validation_0-logloss:0.37622
# [160]	validation_0-logloss:0.37625
# [161]	validation_0-logloss:0.37624
# [162]	validation_0-logloss:0.37619
# [163]	validation_0-logloss:0.37608
# [164]	validation_0-logloss:0.37606
# [165]	validation_0-logloss:0.37607
# [166]	validation_0-logloss:0.37609
# [167]	validation_0-logloss:0.37613
# [168]	validation_0-logloss:0.37617
# [169]	validation_0-logloss:0.37616
# [170]	validation_0-logloss:0.37618
# [171]	validation_0-logloss:0.37617
# [172]	validation_0-logloss:0.37617
# [173]	validation_0-logloss:0.37622
# [174]	validation_0-logloss:0.37622
# [175]	validation_0-logloss:0.37622
# [176]	validation_0-logloss:0.37625
# [177]	validation_0-logloss:0.37621
# [178]	validation_0-logloss:0.37623
# [179]	validation_0-logloss:0.37620
# [180]	validation_0-logloss:0.37615
# [181]	validation_0-logloss:0.37611
# [182]	validation_0-logloss:0.37613
# [183]	validation_0-logloss:0.37606
# [184]	validation_0-logloss:0.37605
# [185]	validation_0-logloss:0.37610
# [186]	validation_0-logloss:0.37608
# [187]	validation_0-logloss:0.37603
# [188]	validation_0-logloss:0.37598
# [189]	validation_0-logloss:0.37597
# [190]	validation_0-logloss:0.37597
# [191]	validation_0-logloss:0.37598
# [192]	validation_0-logloss:0.37593
# [193]	validation_0-logloss:0.37588
# [194]	validation_0-logloss:0.37593
# [195]	validation_0-logloss:0.37594
# [196]	validation_0-logloss:0.37602
# [197]	validation_0-logloss:0.37606
# [198]	validation_0-logloss:0.37610
# [199]	validation_0-logloss:0.37612
# [200]	validation_0-logloss:0.37604
# [201]	validation_0-logloss:0.37612
# [202]	validation_0-logloss:0.37610
# [203]	validation_0-logloss:0.37620
# [204]	validation_0-logloss:0.37627
# [205]	validation_0-logloss:0.37630
# [206]	validation_0-logloss:0.37626
# [207]	validation_0-logloss:0.37622
# [208]	validation_0-logloss:0.37625
# [209]	validation_0-logloss:0.37619
# [210]	validation_0-logloss:0.37622
# [211]	validation_0-logloss:0.37622
# [212]	validation_0-logloss:0.37621
# [213]	validation_0-logloss:0.37629
# [214]	validation_0-logloss:0.37632
# [215]	validation_0-logloss:0.37632
# [216]	validation_0-logloss:0.37633
# [217]	validation_0-logloss:0.37631
# [218]	validation_0-logloss:0.37634
# [219]	validation_0-logloss:0.37631
# [220]	validation_0-logloss:0.37635
# [221]	validation_0-logloss:0.37635
# [222]	validation_0-logloss:0.37631
# [223]	validation_0-logloss:0.37640
# [224]	validation_0-logloss:0.37636
# [225]	validation_0-logloss:0.37633
# [226]	validation_0-logloss:0.37640
# [227]	validation_0-logloss:0.37639
# [228]	validation_0-logloss:0.37640
# [229]	validation_0-logloss:0.37635
# [230]	validation_0-logloss:0.37636
# [231]	validation_0-logloss:0.37635
# [232]	validation_0-logloss:0.37633
# [233]	validation_0-logloss:0.37636
# [234]	validation_0-logloss:0.37636
# [235]	validation_0-logloss:0.37636
# [236]	validation_0-logloss:0.37641
# [237]	validation_0-logloss:0.37641
# [238]	validation_0-logloss:0.37641
# [239]	validation_0-logloss:0.37640
# [240]	validation_0-logloss:0.37642
# [241]	validation_0-logloss:0.37643
# [242]	validation_0-logloss:0.37652
# [243]	validation_0-logloss:0.37652
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print(accuracy_score(model.predict(X_test), y_test))
# Out:
# 0.8283750459100687

# %% [markdown]
# # Save the model

# %%
import xgboost as xgb
model.save_model("predictor.json")

# %% [markdown]
# # Load the model

# %%
# import xgboost as xgb
# model = xgb.XGBClassifier()
# model.load_model("xgb_model.json")
